# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-17 15:16:49--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   174MB/s    in 0.4s
#
# 2022-06-17 15:16:50 (174 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 16552  1704.00849v3  Building a voice conversion (VC) system from n...    cs
# 9231   1706.07276v1  Word embedding models such as Skip-gram learn ...    cs
# 6740   1705.09303v1  It can be difficult to tell whether a trained ...    cs
# 20185  1501.00601v3  We propose that Solomonoff induction is comple...    cs
# 20783  1702.03401v1  This paper has three main contributions to our...    cs
# ...             ...                                                ...   ...
# 7769   1803.02603v1  We present a model that can automatically lear...  stat
# 40765   1305.3149v1  The study focused on the machine learning anal...    cs
# 7996   1710.08266v1  In this paper, we propose deep learning archit...  stat
# 20424  1601.00529v2  In previous work, we proposed a logic-based fr...    cs
# 13352   1009.4984v1  Artificial neural networks have been successfu...    cs
#
#                                                    title  year  \
# 16552  Voice Conversion from Unaligned Corpora using ...  2017
# 9231   Jointly Learning Word Embeddings and Latent To...  2017
# 6740   Latent Geometry and Memorization in Generative...  2017
# 20185  Ultimate Intelligence Part I: Physical Complet...  2015
# 20783  A Minimax Algorithm Better Than Alpha-beta?: N...  2017
# ...                                                  ...   ...
# 7769   Gaussian Process Latent Variable Alignment Lea...  2018
# 40765  Qualitative detection of oil adulteration with...  2013
# 7996   Deep Learning applied to Road Traffic Speed fo...  2017
# 20424     Programming in logic without logic programming  2016
# 13352   Rule Extraction using Artificial Neural Networks  2010
#
#                                                 keywords
# 16552  [conversion, challenging, application, scenari...
# 9231   [embedding, representation, collocation, distr...
# 6740   [difficult, generative, memorized, published, ...
# 20185  [solomonoff, induction, arguments, solomonoff,...
# 20783  [contributions, understanding, formulation, st...
# ...                                                  ...
# 7769   [automatically, alignments, dimensional, unsup...
# 40765  [approaches, adulteration, qualitatively, foll...
# 7996   [architectures, regression, dependent, algorit...
# 20424  [framework, computation, execution, antecedent...
# 13352  [artificial, successfully, application, involv...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 16552    [conversion, challenging, application, scenari...
# 9231     [embedding, representation, collocation, distr...
# 6740     [difficult, generative, memorized, published, ...
# 20185    [solomonoff, induction, arguments, solomonoff,...
# 20783    [contributions, understanding, formulation, st...
#                                ...
# 6024     [recommending, particular, interested, practic...
# 21439    [describes, generative, application, automatic...
# 12264    [classification, performance, classification, ...
# 6773     [generalized, extension, stochastic, successfu...
# 40815    [representations, representations, relations, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8797 words.
# Out of those 4571 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="edf4caf0-b82a-46b9-8b10-c58ab321bb83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edf4caf0-b82a-46b9-8b10-c58ab321bb83")) {                    Plotly.newPlot(                        "edf4caf0-b82a-46b9-8b10-c58ab321bb83",                        [{"x":["conversion","generative","capability","demonstrate","observations","application","autoencoding","transformation","explicitly","objective","situations","languages","wasserstein","explaining","corroborate","alignment","framework","scenarios","experimental","variables","bypassing","considers","requirement","different","variational","adversarial","challenging","unaligned","embedding","represent","representation","paradigms","documents","occurrences","improving","naturally","distributions","embeddings","efficient","effective","complementary","conversely","collocation","occurrence","interaction","addresses","difficult","displaying","memorization","concentrated","techniques","generated","probability","impossible","published","essentially","measurement","memorized","understanding","generator","functions","dissolves","intelligence","mechanics","arguments","reference","applicable","proposals","introduce","complexity","ramifications","universal","induction","completeness","formulation","structures","essential","drawbacks","measurements","tournament","attention","presented","differences","realization","facilitates","practical","construction","publications","deepening","iterative","contributions","transforming","performance","algorithms","perceived","algorithm","currently","significant","distribution","extremely","analyzing","applications","incomplete","including","furthermore","discriminate","statistics","successfully","important","asymptotically","classification","statistically","experiments","dimensional","selection","theoretically","divergence","measuring","designing","synthetic","discrepancy","detection","hypothesis","interpretable","specifically","inference","estimator","connection","opportunities","intellectual","illustrative","satisfying","advancement","communication","completion","responses","conversational","establish","belonging","recognize","responsibility","development","awareness","appropriate","emotional","dynamically","engagement","technologies","generation","throughout","interpersonal","challenges","assistants","affection","ubiquitous","inception","conversation","conversations","intelligent","architecture","initialization","requiring","affecting","computational","alternate","redundant","observation","intensive","retraining","architectures","activations","increasing","parameters","increases","optimizes","regardless","compression","iteratively","achieving","activation","unimportant","attribute","convenient","attributes","viewpoint","statistical","observational","limitations","fundamental","predictor","formalizing","reasoning","causality","generating","conclusively","subtleties","criterion","discrimination","previously","resolving"],"y":[11,110,55,569,72,236,3,68,78,143,46,112,10,12,7,53,527,97,363,124,2,35,32,749,54,94,241,2,114,127,375,16,68,14,101,54,92,85,436,256,41,7,2,31,81,49,136,4,6,4,408,180,166,13,34,14,26,3,156,32,235,2,92,7,11,65,42,28,352,245,1,42,27,12,102,136,63,16,34,2,165,182,48,9,12,144,78,8,2,75,53,14,866,619,7,802,49,222,209,44,57,401,34,235,166,11,50,75,400,15,507,13,625,179,177,48,24,36,54,147,11,325,46,33,164,188,20,47,21,3,4,13,3,55,33,25,15,59,15,57,3,129,8,77,11,26,8,32,148,19,2,110,4,2,13,16,11,9,48,259,18,46,12,265,8,29,60,28,5,137,20,96,245,47,11,14,44,31,86,34,2,32,18,64,19,170,4,59,86,20,4,133,8,89,1,2,38,26,101,7],"type":"bar"},{"x":["conversion","generative","capability","demonstrate","observations","application","autoencoding","transformation","expl ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4571,), (4571, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8058333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>Improves</span> <span style=''>Template</span> <span style=''>Matching</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Normalized</span> <span style=''>Cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlation</span> <br/><br/><span style=''>Template</span> <span style=''>matching</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalized</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>(NCC)</span> <span style=''>is</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>for</span> <span style=''>finding</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.8);'>correspondences</span> <span style=''>We</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.7297297297297298);'>preprocessing</span> <span style=''>images</span> <span style=''>with</span> <span style=''>siamese</span> <span style='background-color:rgba(0, 255, 0, 0.634453781512605);'>convolutional</span> <span style=''>networks</span> <span style=''>trained</span> <span style=''>to</span> <span style=''>maximize</span> <span style=''>the</span> <span style=''>contrast</span> <span style=''>between</span> <span style=''>NCC</span> <span style=''>values</span> <span style=''>of</span> <span style=''>true</span> <span style=''>and</span> <span style=''>false</span> <span style=''>matches</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>improvement</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>quantified</span> <span style=''>using</span> <span style=''>patches</span> <span style=''>of</span> <span style=''>brain</span> <span style=''>images</span> <span style=''>from</span> <span style=''>serial</span> <span style=''>section</span> <span style=''>electron</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>microscopy</span> <span style=''>Relative</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>tuned</span> <span style=''>bandpass</span> <span style=''>filter</span> <span style=''>siamese</span> <span style='background-color:rgba(0, 255, 0, 0.634453781512605);'>convolutional</span> <span style=''>networks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>reduce</span> <span style=''>false</span> <span style=''>matches</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>all</span> <span style=''>false</span> <span style=''>matches</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eliminated</span> <span style=''>by</span> <span style=''>removing</span> <span style=''>a</span> <span style=''>tiny</span> <span style=''>fraction</span> <span style=''>of</span> <span style=''>all</span> <span style=''>matches</span> <span style=''>based</span> <span style=''>on</span> <span style=''>NCC</span> <span style=''>values</span> <span style=''>The</span> <span style=''>improved</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>our</span> <span style=''>method</span> <span style=''>could</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>essential</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>connectomics</span> <span style=''>because</span> <span style=''>emerging</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Truncated</span> <span style=''>Variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reduction</span> <span style=''>A</span> <span style=''>Unified</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>and</span> <span style=''>Level</span> <span style=''>Set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>truncated</span> <span style=''>variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>(TruVaR)</span> <span style=''>that</span> <span style=''>treats</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>(BO)</span> <span style=''>and</span> <span style=''>level</span> <span style=''>set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>(LSE)</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>in</span> <span style=''>a</span> <span style=''>unified</span> <span style=''>fashion</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>greedily</span> <span style=''>shrinks</span> <span style=''>a</span> <span style=''>sum</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>truncated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variances</span> <span style=''>within</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>maximizers</span> <span style=''>(BO)</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unclassified</span> <span style=''>points</span> <span style=''>(LSE)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>updated</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style=''>bounds</span> <span style=''>TruVaR</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>in</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>settings</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>non</span> <span style=''>trivial</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>into</span> <span style=''>myopic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>pointwise</span> <span style=''>costs</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heteroscedastic</span> <span style=''>noise</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantee</span> <span style=''>for</span> <span style=''>TruVaR</span> <span style=''>covering</span> <span style=''>these</span> <span style=''>aspects</span> <span style=''>and</span> <span style=''>use</span> <span style=''>it</span> <span style=''>to</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Bounded</span> <span style=''>Optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Exploration</span> <span style=''>in</span> <span style=''>MDP</span> <br/><br/><span style=''>Within</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>probably</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximately</span> <span style=''>correct</span> <span style=''>Markov</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>(PAC</span> <span style=''>MDP)</span> <span style=''>much</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style=''>work</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>attain</span> <span style=''>near</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimality</span> <span style=''>after</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>long</span> <span style=''>period</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>concerns</span> <span style=''>require</span> <span style=''>the</span> <span style=''>attainment</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7647058823529411);'>satisfactory</span> <span style=''>behavior</span> <span style=''>within</span> <span style=''>a</span> <span style=''>short</span> <span style=''>period</span> <span style=''>of</span> <span style=''>time</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>relax</span> <span style=''>the</span> <span style=''>PAC</span> <span style=''>MDP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>reconcile</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretically</span> <span style=''>driven</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>methods</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>needs</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>discrete</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>state</span> <span style=''>spaces</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustrate</span> <span style=''>the</span> <span style=''>benefits</span> <span style=''>of</span> <span style=''>our</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relaxation</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style=''>analyses</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>numerical</span> <span style=''>examples</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>also</span> <span style=''>maintain</span> <span style=''>anytime</span> <span style=''>error</span> <span style=''>bounds</span> <span style=''>and</span> <span style=''>average</span> <span style=''>loss</span> <span style=''>bounds</span> <span style=''>Our</span> <span style=''>approach</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transforms</span> <span style=''>for</span> <span style=''>Small</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Footprint</span> <span style=''>Deep</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style=''>building</span> <span style=''>compact</span> <span style=''>deep</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>pipelines</span> <span style=''>suitable</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deployment</span> <span style=''>on</span> <span style=''>storage</span> <span style=''>and</span> <span style=''>power</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>mobile</span> <span style=''>devices</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>matrices</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterized</span> <span style=''>by</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>displacement</span> <span style=''>rank</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforms</span> <span style=''>admit</span> <span style=''>fast</span> <span style=''>function</span> <span style=''>and</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>and</span> <span style=''>span</span> <span style=''>a</span> <span style=''>rich</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>sharing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>configurations</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>modeling</span> <span style=''>capacity</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style=''>tuned</span> <span style=''>along</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuum</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unstructured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experimental</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforms</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>and</span> <span style=''>forwardbackward</span> <span style=''>passes</span> <span style=''>during</span> <span style=''>training</span> <span style=''>and</span> <span style=''>offer</span> <span style=''>superior</span> <span style=''>accuracy</spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13038793103448276)
# 	segmentation (0.06932471264367816)
# 	knowledge (0.1278735632183908)
# 	architecture (0.09303160919540229)
# 	information (0.2449712643678161)
# 	representation (0.13469827586206898)
# 	detection (0.11673850574712644)
# 	different (0.26903735632183906)
# 	convolutional (0.13972701149425287)
# 	recognition (0.14295977011494254)
#
# Some Statistics words are:
# 	variables (0.12946428571428573)
# 	convergence (0.125)
# 	statistical (0.15029761904761904)
# 	stochastic (0.13690476190476192)
# 	estimation (0.1701388888888889)
# 	algorithm (0.3933531746031746)
# 	distribution (0.18501984126984128)
# 	inference (0.1939484126984127)
# 	dimensional (0.1949404761904762)
# 	regression (0.17906746031746032)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="05b51099-75fe-4e29-87f4-10e4a0b857ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05b51099-75fe-4e29-87f4-10e4a0b857ff")) {                    Plotly.newPlot(                        "05b51099-75fe-4e29-87f4-10e4a0b857ff",                        [{"x":["conversion","generative","capability","demonstrate","observations","application","autoencoding","transformation","explicitly","objective","situations","languages","wasserstein","explaining","corroborate","alignment","framework","scenarios","experimental","variables","bypassing","considers","requirement","different","variational","adversarial","challenging","unaligned","embedding","represent","representation","paradigms","documents","occurrences","improving","naturally","distributions","embeddings","efficient","effective","complementary","conversely","collocation","occurrence","interaction","addresses","difficult","displaying","memorization","concentrated","techniques","generated","probability","impossible","published","essentially","measurement","memorized","understanding","generator","functions","dissolves","intelligence","mechanics","arguments","reference","applicable","proposals","introduce","complexity","ramifications","universal","induction","completeness","formulation","structures","essential","drawbacks","measurements","tournament","attention","presented","differences","realization","facilitates","practical","construction","publications","deepening","iterative","contributions","transforming","performance","algorithms","perceived","algorithm","currently","significant","distribution","extremely","analyzing","applications","incomplete","including","furthermore","discriminate","statistics","successfully","important","asymptotically","classification","statistically","experiments","dimensional","selection","theoretically","divergence","measuring","designing","synthetic","discrepancy","detection","hypothesis","interpretable","specifically","inference","estimator","connection","opportunities","intellectual","illustrative","satisfying","advancement","communication","completion","responses","conversational","establish","belonging","recognize","responsibility","development","awareness","appropriate","emotional","dynamically","engagement","technologies","generation","throughout","interpersonal","challenges","assistants","affection","ubiquitous","inception","conversation","conversations","intelligent","architecture","initialization","requiring","affecting","computational","alternate","redundant","observation","intensive","retraining","architectures","activations","increasing","parameters","increases","optimizes","regardless","compression","iteratively","achieving","activation","unimportant","attribute","convenient","attributes","viewpoint","statistical","observational","limitations","fundamental","predictor","formalizing","reasoning","causality","generating","conclusively","subtleties","criterion","discrimination","previously","resolving","articulate","protected","implement","dependency","properties","dependence","extracting","information","relations","retrieval","classifiers","connectives","extraction","collected","extracted","mechanisms","opportunity","sentences","investigation","analysing","accidents","processing","facilitate","connecting","feasibility","organizational","regression","expressions","comparisons","supervised","estimators","completely","formulate","cardinality","estimation","unlabeled","recognition","knowledge","resulting","formulated","selecting","motivating","characterized","selective","sequences","dimensions","numerical","simulations","contribution","performances","corrected","detecting","conditional","parameter","eliminated","unsupervised","generalized","compressors","c ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	illustrations
# 	convolved
# 	ancestral
# 	unconfounded
# 	martingales
# 	confounded
# 	crowdworkers
# 	barycenter
# 	statisticians
# 	forecasters
# 	specialist
# 	nonasymptotic
# 	bijective
# 	gaussianity
# 	spectroscopy
# 	staleness
# 	penalization
# 	increments
# 	exchangeable
# 	suboptimality
# Some words which never appear in Statistics papers:
# 	bypassing
# 	collocation
# 	memorized
# 	dissolves
# 	deepening
# 	intellectual
# 	conversational
# 	responsibility
# 	interpersonal
# 	assistants
# 	affection
# 	conversations
# 	unimportant
# 	connectives
# 	accidents
# 	organizational
# 	ascending
# 	compilation
# 	instruction
# 	reconfigurable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.085372250161982e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
